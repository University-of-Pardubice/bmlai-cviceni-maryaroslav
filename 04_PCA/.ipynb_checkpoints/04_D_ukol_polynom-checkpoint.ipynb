# %% [markdown]
# # Polynominální regrese
#
# ## Úkol
#
# - Načtěte dataset s velikostmi a cenami
# - Prozkoumejte a zobrazte data
# - Vytvořte lineární model a zjistětě jaho R2
# - Vytvořte polynomiální modely s různým stupni, zjistěte jejich R2
# - Vyberte nejlepší model

# %% [markdown]
# # Načtení dat

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
data = pd.read_csv ("..\dataset\prices.csv",  sep=';')

# %%
data.head()
# Out:
#         Size       Price
# 0   51.00000   901.18810
# 1   70.36735   972.23867
# 2   89.73469  1001.99394
# 3  109.10204  1024.90830
# 4  128.46939  1053.72491

# %% [markdown]
# # Lineární model
# - standardizujte data
# - vytvořte a natrénujte lineární model
# - zobrazte parametry modelu
# - vizualizujte lineární model
# - zobrazte skóre modelu

# %%
def rescale(X):
    mean = X.mean()
    std = X.std()
    scaled_X = [(i - mean)/std for i in X]
    return pd.Series(scaled_X)

# %%
data_std = pd.DataFrame(columns=data.columns)
for i in data.columns:
    data_std[i] = rescale(data[i])

# %%
data_std.describe()
# Out:
#                Size         Price
# count  6.200000e+01  6.200000e+01
# mean   3.187414e-16 -2.467560e-15
# std    1.000000e+00  1.000000e+00
# min   -1.690536e+00 -2.877085e+00
# 25%   -8.452679e-01 -5.836494e-01
# 50%    1.186304e-08  2.048456e-01
# 75%    8.452678e-01  8.083945e-01
# max    1.690536e+00  1.348537e+00

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
X = np.array(data.drop('Price',axis=1))
Y = np.array(data['Price'])
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
lr = LinearRegression()
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X_train, Y_train, color='blue', label='Trénovací data')
plt.scatter(X_test, Y_test, color='green', label='Testovací data')
plt.xlabel('Standardizovaná velikost')
plt.ylabel('Cena')
plt.title('Lineární model')
plt.legend()
plt.show()

# %%
train_score = lr.score(X_train, Y_train)
test_score = lr.score(X_test, Y_test)
print("\nSkóre modelu (R^2):")
print(fX_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)"Trénovací data: {train_score:.4f}")
print(f"Testovací data: {test_score:.4f}")
# Out:
# Skóre modelu (R^2):
# Trénovací data: 0.3993
# Testovací data: 0.6483

# %% [markdown]
# # Vytvořte polynominální regresní model
# - vytvořte model polynominální 1D model se stupni 2 - 8
# - modely zobrazte
# - zobrazte jejich parametry
# - zobrazte jejich skóre
# - Který model byste vybrali?

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
def polynomial_fit(X, Y, degree=1):
    return np.poly1d(np.polyfit(X.ravel(), Y.ravel(), degree))

# %%
def visualize_model (p, X_train, Y_train, X_test, Y_test, degree, x_label = "Size", y_label = "Price"):              
    fig1 = plt.figure()    
    plt.scatter (X_train, Y_train, c='r', label="Train ")
    plt.scatter (X_test, Y_test, c='b', label="Test ")
    
    curve_x = np.arange(X_train.min(), max(X_train.max(), X_test.max()), 0.01)
    plt.plot(curve_x, p(curve_x), label=f"Polynomial of degree {degree}")  
            
    plt.title ("Model")
    plt.ylabel(x_label)
    plt.xlabel(y_label)
    plt.legend()
    plt.show()

# %%
for degree in range (2, 8):
    p = polynomial_fit(X_train, Y_train, degree)  
    visualize_model (p, X_train, Y_train, X_test, Y_test, degree)    
    print("Váhy: ", p.coef)
print_model_score(Y_train, p(X_train.ravel()), "Train")
print_model_score(Y_test, p(X_test.ravel()), "Test")
# Out:
# Váhy:  [-8.87470984e-04  1.44664486e+00  8.70826748e+02]
# Váhy:  [-6.00676239e-07  2.66196652e-04  8.43854260e-01  9.38587435e+02]
# Váhy:  [-3.89971431e-09  9.52529963e-06 -8.34970220e-03  3.46415706e+00
#   7.48054985e+02]
# Váhy:  [-1.89493261e-12  2.31024435e-09  2.14412494e-06 -4.52298539e-03
#   2.65957618e+00  7.93693704e+02]
# Váhy:  [-4.82426321e-15  1.68702682e-11 -2.57544146e-08  2.23281223e-05
#  -1.16289361e-02  3.75365264e+00  7.42653374e+02]
# Váhy:  [ 2.59740611e-18 -1.64952808e-14  3.78075541e-11 -4.48536585e-08
#   3.16575986e-05 -1.39799446e-02  4.02160958e+00  7.32593732e+02]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 5
#       3     visualize_model (p, X_train, Y_train, X_test, Y_test, degree)
#       4     print("Váhy: ", p.coef)
# ----> 5 print_model_score(Y_train, p(X_train.ravel()), "Train")
#       6 print_model_score(Y_test, p(X_test.ravel()), "Test")
#
# NameError: name 'print_model_score' is not defined
